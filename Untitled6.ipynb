# %% [markdown]
# <a href="https://colab.research.google.com/github/grace-116/colab-python1/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Advanced. 논문/보고서용 지수 표기법 (Uncertainty나 아주 작은 확률값)
prob = 0.000000045678
print(f"실패 확률: {prob:.3e}")  # 결과: 4.568e-08 -> 뜻 : 4.568 × 10^-8
print(f"실패 확률: {prob:.4f}")  # 결과: 0.000
#.3e : 지수 표기법, 소수점 이하 3자리
#.4f : 고정 소수점, 소수점 이하 4자리

# %%
# 객체 자료형 확인
print(type(10))
print(type(3.14))
print(type("Hello"))

# 정수와 문자열을 실수로 변환하기
a = float(10)
b = float("3.14")

print(a, type(a))
print(b, type(b))

# %%
#divmod는 몫과 나머지 함께 출력
print(divmod(17, 5))
ahr, skajwl = divmod(17, 5)
print(ahr)
print(skajwl)

# %%
# 1. 25를 7로 나눈 몫과 나머지를 divmod로 구하기
print(divmod(25,7))
# 2. 0b1010과 5.5를 더하고, 결과값 출력 및 자료형 확인하기
result = 0b1010+5.5
print(result)
print(type(result))
# Out:
# (3, 4)
# 15.5
# <class 'float'>

# %%
#변수 삭제하기
temp = 50
del temp
#print(temp)
